# %%
import os

import matplotlib.pyplot
import matplotlib.pyplot as plt
import numpy
import numpy as np
import pandas
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import umap
from matplotlib.colors import LogNorm
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import (adjusted_rand_score, completeness_score,
                             homogeneity_score, mean_absolute_error,
                             normalized_mutual_info_score, r2_score,
                             silhouette_score)
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset, random_split
from tqdm import tqdm
from transformers import AutoModel, AutoTokenizer

torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True
torch.backends.cudnn.benchmark = True

import os

os.environ["TOKENIZERS_PARALLELISM"] = "false"

import torch.multiprocessing as mp

mp.set_start_method("spawn", force=True)

name = "Huber_latest"

# %%
# %load_ext autoreload
# %autoreload 2

from utils import *
from VAE_GDSC import GDSCDataset, GeneDrugVAE

# %%
cellline = pd.read_csv(
    "../dataset/gdsc/cellline_info.csv.gz",
    usecols=["COSMIC_ID", "SMILES", "NAME", "Z_score"],
)
exp = pd.read_csv("../dataset/gdsc/exp.csv.gz", index_col=0)

# %%
# 学習済みモデルの指定（ChemBERTa）
MODEL_NAME = "seyonec/ChemBERTa-zinc-base-v1"

# トークナイザーとモデルをロード
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModel.from_pretrained(MODEL_NAME)

# GPUが使える場合はGPUに
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
smiles_list = cellline["SMILES"].unique().tolist()

inputs = tokenizer(smiles_list, padding=True, truncation=True, return_tensors="pt")
inputs = {k: v.to(device) for k, v in inputs.items()}

with torch.no_grad():
    outputs = model(**inputs)
    embeddings = outputs.last_hidden_state[:, 0, :]  # [batch_size, hidden_size]

# %%
drugs = pd.DataFrame(embeddings.cpu().numpy())
drugs.index = smiles_list

# %%
exp.index = exp.index.astype(str)
cellline["COSMIC_ID"] = cellline["COSMIC_ID"].astype(str)
drugs.index = drugs.index.astype(str)

# %%
exp_values = exp.to_numpy(dtype=np.float32)
cid_to_row = {cid: i for i, cid in enumerate(exp.index)}
drug_vec = {s: drugs.loc[s].to_numpy(dtype=np.float32) for s in drugs.index}
mask = cellline["COSMIC_ID"].isin(exp.index) & cellline["SMILES"].isin(drugs.index)
cellline_small = cellline.loc[mask].reset_index(drop=True)
print(f"usable pairs: {len(cellline_small):,} / {len(cellline):,}")
# Out:
# usable pairs: 284,826 / 284,826

# %%
print("n_sample:", cellline_small.shape[0])
# Out:
# n_sample: 284826

# %%
batch_size = 16384
num_epochs = 100

rec_w = 0.16  # 0.18→0.16：再構成をさらに弱め、z活用を推進
lam = 2.9  # 3.0→2.9：KLの寄与をほんのり下げて分散過多を防止
beta_max = 1.02  # 1.00→1.02：後半のKL膨張を軽くブレーキ
gamma = 2.5  # 2.3→2.5：C寄せを強化し安定性アップ

C_max = 0.075  # 0.07→0.075：KLの目標をやや上げて潜在表現を厚めに
C_steps = 280  # 240→280：スケジュールを滑らかに伸ばして安定追従

lr = 1e-3
weight_decay = 9e-4  # 1e-3→9e-4：ほんの少し緩め、表現力を残す

# %%
ds = GDSCDataset(
    cellline_small,
    exp_values,
    cid_to_row,
    drug_vec,
    dtype=torch.float32,
    pin_memory=True,
    copy_arrays=False,
    #     materialize="none",    # ← これが重要！前展開を完全禁止
    #     ram_limit_gb=0.5       # （任意）auto を使う時の安全枠も小さくできる
)

# %%
val_ratio = 0.2
n_total = len(ds)
n_val = int(n_total * val_ratio)
n_train = n_total - n_val

# 再現性
g = torch.Generator().manual_seed(42)
train_ds, val_ds = random_split(ds, [n_train, n_val], generator=g)

# %%
train_dl = DataLoader(
    train_ds,
    batch_size=batch_size,  # GPU メモリに合わせて調整（8k〜32k 目安）
    shuffle=True,
    num_workers=1,
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=4,
    drop_last=True,
)

# %%
val_dl = DataLoader(
    val_ds,
    batch_size=batch_size,  # 余裕があれば少し大きめ
    shuffle=False,  # 検証はシャッフル不要
    num_workers=1,  # ここは少なめでもOK
    pin_memory=True,
    persistent_workers=True,
    prefetch_factor=2,
    drop_last=False,
)

# %%
gene_dim = exp_values.shape[1]
smiles_dim = 768

device = (
    torch.device("cuda")
    if torch.cuda.is_available()
    else (
        torch.device("mps")
        if torch.backends.mps.is_available()
        else torch.device("cpu")
    )
)
device_type = (
    "cuda" if device.type == "cuda" else ("mps" if device.type == "mps" else "cpu")
)

use_amp = device_type in ("cuda", "mps")

# GradScaler は CUDA のみ
scaler = torch.amp.GradScaler(enabled=(device_type == "cuda"))

# %%
os.makedirs("models/gdsc", exist_ok=True)

best_val = float("inf")
best_path = f"models/gdsc/gdsc_best_{name}.pt"

# --- logs / histories ---
train_hist, val_hist, elbo_val_hist = [], [], []
train_rec_hist, train_kl_hist, train_z_hist = [], [], []
val_rec_hist, val_kl_hist, val_z_hist = [], [], []
train_capgap_hist, val_capgap_hist, C_values = [], [], []

model = GeneDrugVAE(
    gene_dim, drug_dim=smiles_dim, proj_dim=256, hidden=512, latent=128
).to(device)

# 1) Optimizer を param group で作り直し
head_params = list(model.head.parameters())
base_params = [p for n, p in model.named_parameters() if not n.startswith("head.")]

opt = torch.optim.Adam(
    [
        {"params": base_params, "lr": lr, "weight_decay": 1e-3},
        {"params": head_params, "lr": lr * 0.5, "weight_decay": 5e-3},  # ← LR↓, WD↑
    ]
)


def _avg(sum_val, cnt):
    return sum_val / max(cnt, 1)


beta_warmup_epochs = int(0.5 * num_epochs)
for ep in range(num_epochs):
    # === 追加：このepochのβ（0→1に線形） ===
    beta = beta_max * min(1.0, (ep + 1) / beta_warmup_epochs)

    model.train()
    C = C_max * (ep / C_steps) if ep < C_steps else C_max
    C_values.append(C)

    # ---- training ----
    m_total = n_batches = 0
    rec_sum = kl_sum = z_sum = capgap_sum = 0.0
    n_train_samples = 0

    for bidx, (xg, xd, y) in enumerate(
        tqdm(train_dl, desc=f"Train E{ep+1}", leave=False)
    ):
        if ep == 0 and bidx == 0:
            print(
                f"[LR] base={opt.param_groups[0]['lr']:.2e} | head={opt.param_groups[1]['lr']:.2e}"
            )

        xg = xg.to(device, non_blocking=True)
        xd = xd.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)
        opt.zero_grad(set_to_none=True)

        with torch.amp.autocast(device_type=device_type, enabled=use_amp):
            recon, mu, lv, yhat = model(xg, xd)
            rec = F.mse_loss(recon, xg, reduction="mean")
            kl = 0.5 * (-1 - lv + mu.pow(2) + lv.exp()).sum(dim=1).mean()
            zloss = F.smooth_l1_loss(yhat, y, beta=1, reduction="mean")  # Huber
            gap_abs = torch.abs(kl - C)
            gap_sq = (kl - C) ** 2
            loss = rec_w * rec + beta * kl + gamma * gap_sq + lam * zloss

        if device_type == "cuda":
            prev_scale = scaler.get_scale()
            scaler.scale(loss).backward()
            scaler.unscale_(opt)  # ← これを追加してからクリップ
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            scaler.step(opt)
            scaler.update()
        else:
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            opt.step()

        bs = xg.size(0)
        m_total += loss.item()
        n_batches += 1
        rec_sum += rec.item() * bs
        kl_sum += kl.item() * bs
        z_sum += zloss.item() * bs
        capgap_sum += gap_abs.item() * bs
        n_train_samples += bs

    train_loss = m_total / n_batches
    train_hist.append(train_loss)
    train_rec_hist.append(_avg(rec_sum, n_train_samples))
    train_kl_hist.append(_avg(kl_sum, n_train_samples))
    train_z_hist.append(_avg(z_sum, n_train_samples))
    train_capgap_hist.append(_avg(capgap_sum, n_train_samples))

    # ---- validation ----
    model.eval()
    val_loss_sum = 0.0
    n_val_batches = 0
    v_rec_sum = v_kl_sum = v_z_sum = v_capgap_sum = 0.0
    n_val_samples = 0
    elbo_val_sum = 0.0

    with torch.no_grad():
        for xg, xd, y in val_dl:
            xg, xd, y = xg.to(device), xd.to(device), y.to(device)
            recon, mu, lv, yhat = model(xg, xd)
            rec = F.mse_loss(recon, xg, reduction="mean")
            kl = 0.5 * (-1 - lv + mu.pow(2) + lv.exp()).sum(dim=1).mean()
            zloss = F.smooth_l1_loss(yhat, y, beta=1, reduction="mean")  # Huber
            gap_abs = torch.abs(kl - C)  # ← 追加：ログ用
            gap_sq = (kl - C) ** 2  # ← 追加：損失用（二乗）

            loss = rec_w * rec + beta * kl + gamma * gap_sq + lam * zloss
            elbo_loss = rec + beta * kl + lam * zloss

            bs = xg.size(0)
            val_loss_sum += loss.item()
            n_val_batches += 1
            v_rec_sum += rec.item() * bs
            v_kl_sum += kl.item() * bs
            v_z_sum += zloss.item() * bs
            v_capgap_sum += gap_abs.item() * bs  # ← 置換：capgap → gap_abs
            n_val_samples += bs
            elbo_val_sum += elbo_loss.item() * bs

    val_loss = val_loss_sum / n_val_batches
    val_hist.append(val_loss)
    val_rec_hist.append(_avg(v_rec_sum, n_val_samples))
    val_kl_hist.append(_avg(v_kl_sum, n_val_samples))
    val_z_hist.append(_avg(v_z_sum, n_val_samples))
    val_capgap_hist.append(_avg(v_capgap_sum, n_val_samples))
    elbo_val_hist.append(_avg(elbo_val_sum, n_val_samples))

    print(
        f"Epoch {ep+1}/{num_epochs} | Train {train_loss:.4f} | Val {val_loss:.4f} | Val(ELBO) {elbo_val_hist[-1]:.4f}"
    )

    print(
        f"  C={C:.3f} | "
        f"KL tr/val={train_kl_hist[-1]:.4f}/{val_kl_hist[-1]:.4f} | "
        f"gap(|KL-C|) tr/val={train_capgap_hist[-1]:.4f}/{val_capgap_hist[-1]:.4f} | "
        f"zloss tr/val={train_z_hist[-1]:.4f}/{val_z_hist[-1]:.4f} | "
        f"rec tr/val={train_rec_hist[-1]:.4f}/{val_rec_hist[-1]:.4f} | "
        f"beta={beta:.4f}, gamma={gamma:.4f}"
    )

    if (ep + 1) % 10 == 0:
        model.eval()
        eval_dl = torch.utils.data.DataLoader(
            val_ds,
            batch_size=8192,
            shuffle=False,
            num_workers=0,
            pin_memory=False,
            persistent_workers=False,
            drop_last=False,
        )
        ys, yhats = [], []
        with torch.inference_mode():
            for xg, xd, y in eval_dl:
                xg, xd = xg.to(device), xd.to(device)
                _, _, _, yhat = model(xg, xd)
                ys.append(y.cpu().numpy())
                yhats.append(yhat.cpu().numpy())
        import numpy as np
        from sklearn.metrics import mean_absolute_error, r2_score

        ys = np.concatenate(ys)
        yhats = np.concatenate(yhats)
        mae = mean_absolute_error(ys, yhats)
        r2 = r2_score(ys, yhats)
        print(f"  [Eval@E{ep+1}] MAE={mae:.4f}, R^2={r2:.4f}")
        print(f"  [Eval@E{ep+1}] yhat mean/std = {yhats.mean():.4f}/{yhats.std():.4f}")

    if val_loss < best_val - 1e-6:
        best_val = val_loss
        torch.save(model.state_dict(), best_path)
        print(f"[Save] Best model updated at epoch {ep+1}: {best_path}")
# Out:
# Train E1:   0%|          | 0/13 [00:00<?, ?it/s]
# [LR] base=1.00e-03 | head=5.00e-04
# Epoch 1/100 | Train 1.3771 | Val 1.3204 | Val(ELBO) 2.1649
#   C=0.000 | KL tr/val=0.0961/0.0636 | gap(|KL-C|) tr/val=0.0961/0.0636 | zloss tr/val=0.4043/0.3957 | rec tr/val=1.0340/1.0162 | beta=0.0204, gamma=2.5000
# [Save] Best model updated at epoch 1: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 2/100 | Train 1.2784 | Val 1.2447 | Val(ELBO) 2.0730
#   C=0.000 | KL tr/val=0.0781/0.0804 | gap(|KL-C|) tr/val=0.0778/0.0801 | zloss tr/val=0.3787/0.3674 | rec tr/val=1.0092/1.0041 | beta=0.0408, gamma=2.5000
# [Save] Best model updated at epoch 2: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 3/100 | Train 1.2075 | Val 1.1832 | Val(ELBO) 2.0070
#   C=0.001 | KL tr/val=0.0901/0.0836 | gap(|KL-C|) tr/val=0.0896/0.0830 | zloss tr/val=0.3521/0.3452 | rec tr/val=1.0023/1.0008 | beta=0.0612, gamma=2.5000
# [Save] Best model updated at epoch 3: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 4/100 | Train 1.1590 | Val 1.1527 | Val(ELBO) 1.9823
#   C=0.001 | KL tr/val=0.0861/0.0659 | gap(|KL-C|) tr/val=0.0852/0.0650 | zloss tr/val=0.3357/0.3369 | rec tr/val=1.0002/0.9999 | beta=0.0816, gamma=2.5000
# [Save] Best model updated at epoch 4: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 5/100 | Train 1.1328 | Val 1.1304 | Val(ELBO) 1.9607
#   C=0.001 | KL tr/val=0.0703/0.0645 | gap(|KL-C|) tr/val=0.0692/0.0634 | zloss tr/val=0.3288/0.3291 | rec tr/val=0.9998/0.9997 | beta=0.1020, gamma=2.5000
# [Save] Best model updated at epoch 5: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 6/100 | Train 1.1189 | Val 1.1219 | Val(ELBO) 1.9568
#   C=0.001 | KL tr/val=0.0610/0.0467 | gap(|KL-C|) tr/val=0.0596/0.0453 | zloss tr/val=0.3250/0.3280 | rec tr/val=0.9996/0.9997 | beta=0.1224, gamma=2.5000
# [Save] Best model updated at epoch 6: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 7/100 | Train 1.1092 | Val 1.1035 | Val(ELBO) 1.9384
#   C=0.002 | KL tr/val=0.0526/0.0482 | gap(|KL-C|) tr/val=0.0510/0.0466 | zloss tr/val=0.3225/0.3213 | rec tr/val=0.9999/0.9997 | beta=0.1428, gamma=2.5000
# [Save] Best model updated at epoch 7: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 8/100 | Train 1.0899 | Val 1.0982 | Val(ELBO) 1.9330
#   C=0.002 | KL tr/val=0.0508/0.0495 | gap(|KL-C|) tr/val=0.0490/0.0476 | zloss tr/val=0.3157/0.3190 | rec tr/val=0.9996/0.9997 | beta=0.1632, gamma=2.5000
# [Save] Best model updated at epoch 8: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 9/100 | Train 1.0800 | Val 1.0872 | Val(ELBO) 1.9222
#   C=0.002 | KL tr/val=0.0470/0.0480 | gap(|KL-C|) tr/val=0.0449/0.0459 | zloss tr/val=0.3125/0.3151 | rec tr/val=0.9998/0.9997 | beta=0.1836, gamma=2.5000
# [Save] Best model updated at epoch 9: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 10/100 | Train 1.0726 | Val 1.0763 | Val(ELBO) 1.9134
#   C=0.002 | KL tr/val=0.0448/0.0401 | gap(|KL-C|) tr/val=0.0424/0.0377 | zloss tr/val=0.3100/0.3122 | rec tr/val=0.9994/0.9997 | beta=0.2040, gamma=2.5000
#   [Eval@E10] MAE=0.6567, R^2=0.2684
#   [Eval@E10] yhat mean/std = -0.0138/0.4668
# [Save] Best model updated at epoch 10: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 11/100 | Train 1.0653 | Val 1.0685 | Val(ELBO) 1.9058
#   C=0.003 | KL tr/val=0.0416/0.0386 | gap(|KL-C|) tr/val=0.0389/0.0360 | zloss tr/val=0.3076/0.3095 | rec tr/val=0.9998/0.9997 | beta=0.2244, gamma=2.5000
# [Save] Best model updated at epoch 11: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 12/100 | Train 1.0542 | Val 1.0580 | Val(ELBO) 1.8951
#   C=0.003 | KL tr/val=0.0399/0.0371 | gap(|KL-C|) tr/val=0.0369/0.0341 | zloss tr/val=0.3038/0.3056 | rec tr/val=0.9996/0.9997 | beta=0.2448, gamma=2.5000
# [Save] Best model updated at epoch 12: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 13/100 | Train 1.0493 | Val 1.0546 | Val(ELBO) 1.8910
#   C=0.003 | KL tr/val=0.0371/0.0398 | gap(|KL-C|) tr/val=0.0339/0.0366 | zloss tr/val=0.3023/0.3037 | rec tr/val=0.9992/0.9997 | beta=0.2652, gamma=2.5000
# [Save] Best model updated at epoch 13: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 14/100 | Train 1.0352 | Val 1.0457 | Val(ELBO) 1.8832
#   C=0.003 | KL tr/val=0.0353/0.0360 | gap(|KL-C|) tr/val=0.0318/0.0326 | zloss tr/val=0.2975/0.3011 | rec tr/val=0.9996/0.9997 | beta=0.2856, gamma=2.5000
# [Save] Best model updated at epoch 14: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 15/100 | Train 1.0297 | Val 1.0373 | Val(ELBO) 1.8751
#   C=0.004 | KL tr/val=0.0335/0.0321 | gap(|KL-C|) tr/val=0.0297/0.0283 | zloss tr/val=0.2956/0.2985 | rec tr/val=0.9994/0.9997 | beta=0.3060, gamma=2.5000
# [Save] Best model updated at epoch 15: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 16/100 | Train 1.0273 | Val 1.0446 | Val(ELBO) 1.8816
#   C=0.004 | KL tr/val=0.0311/0.0370 | gap(|KL-C|) tr/val=0.0271/0.0329 | zloss tr/val=0.2949/0.2999 | rec tr/val=0.9996/0.9997 | beta=0.3264, gamma=2.5000
# Epoch 17/100 | Train 1.0199 | Val 1.0318 | Val(ELBO) 1.8693
#   C=0.004 | KL tr/val=0.0299/0.0332 | gap(|KL-C|) tr/val=0.0256/0.0289 | zloss tr/val=0.2924/0.2959 | rec tr/val=0.9998/0.9997 | beta=0.3468, gamma=2.5000
# [Save] Best model updated at epoch 17: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 18/100 | Train 1.0113 | Val 1.0276 | Val(ELBO) 1.8658
#   C=0.005 | KL tr/val=0.0288/0.0272 | gap(|KL-C|) tr/val=0.0242/0.0226 | zloss tr/val=0.2894/0.2952 | rec tr/val=0.9997/0.9997 | beta=0.3672, gamma=2.5000
# [Save] Best model updated at epoch 18: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 19/100 | Train 1.0092 | Val 1.0163 | Val(ELBO) 1.8548
#   C=0.005 | KL tr/val=0.0275/0.0255 | gap(|KL-C|) tr/val=0.0227/0.0207 | zloss tr/val=0.2887/0.2914 | rec tr/val=0.9997/0.9997 | beta=0.3876, gamma=2.5000
# [Save] Best model updated at epoch 19: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 20/100 | Train 0.9935 | Val 1.0352 | Val(ELBO) 1.8733
#   C=0.005 | KL tr/val=0.0264/0.0229 | gap(|KL-C|) tr/val=0.0213/0.0178 | zloss tr/val=0.2833/0.2980 | rec tr/val=0.9994/0.9997 | beta=0.4080, gamma=2.5000
#   [Eval@E20] MAE=0.6344, R^2=0.2980
#   [Eval@E20] yhat mean/std = 0.0600/0.5264
# Epoch 21/100 | Train 1.0009 | Val 1.0086 | Val(ELBO) 1.8467
#   C=0.005 | KL tr/val=0.0250/0.0238 | gap(|KL-C|) tr/val=0.0196/0.0184 | zloss tr/val=0.2859/0.2886 | rec tr/val=0.9997/0.9997 | beta=0.4284, gamma=2.5000
# [Save] Best model updated at epoch 21: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 22/100 | Train 0.9848 | Val 1.0033 | Val(ELBO) 1.8418
#   C=0.006 | KL tr/val=0.0241/0.0230 | gap(|KL-C|) tr/val=0.0185/0.0174 | zloss tr/val=0.2804/0.2868 | rec tr/val=0.9998/0.9997 | beta=0.4488, gamma=2.5000
# [Save] Best model updated at epoch 22: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 23/100 | Train 0.9807 | Val 1.0008 | Val(ELBO) 1.8390
#   C=0.006 | KL tr/val=0.0238/0.0205 | gap(|KL-C|) tr/val=0.0179/0.0146 | zloss tr/val=0.2789/0.2861 | rec tr/val=0.9995/0.9997 | beta=0.4692, gamma=2.5000
# [Save] Best model updated at epoch 23: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 24/100 | Train 0.9706 | Val 0.9890 | Val(ELBO) 1.8269
#   C=0.006 | KL tr/val=0.0227/0.0237 | gap(|KL-C|) tr/val=0.0165/0.0175 | zloss tr/val=0.2755/0.2813 | rec tr/val=0.9996/0.9997 | beta=0.4896, gamma=2.5000
# [Save] Best model updated at epoch 24: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 25/100 | Train 0.9751 | Val 0.9898 | Val(ELBO) 1.8284
#   C=0.006 | KL tr/val=0.0221/0.0186 | gap(|KL-C|) tr/val=0.0156/0.0122 | zloss tr/val=0.2770/0.2825 | rec tr/val=0.9997/0.9997 | beta=0.5100, gamma=2.5000
# Epoch 26/100 | Train 0.9690 | Val 0.9991 | Val(ELBO) 1.8378
#   C=0.007 | KL tr/val=0.0214/0.0175 | gap(|KL-C|) tr/val=0.0147/0.0108 | zloss tr/val=0.2749/0.2858 | rec tr/val=0.9995/0.9997 | beta=0.5304, gamma=2.5000
# Epoch 27/100 | Train 0.9613 | Val 0.9786 | Val(ELBO) 1.8174
#   C=0.007 | KL tr/val=0.0213/0.0177 | gap(|KL-C|) tr/val=0.0143/0.0107 | zloss tr/val=0.2721/0.2786 | rec tr/val=0.9998/0.9997 | beta=0.5508, gamma=2.5000
# [Save] Best model updated at epoch 27: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 28/100 | Train 0.9491 | Val 0.9802 | Val(ELBO) 1.8183
#   C=0.007 | KL tr/val=0.0202/0.0218 | gap(|KL-C|) tr/val=0.0130/0.0146 | zloss tr/val=0.2680/0.2780 | rec tr/val=0.9997/0.9997 | beta=0.5712, gamma=2.5000
# Epoch 29/100 | Train 0.9456 | Val 0.9748 | Val(ELBO) 1.8138
#   C=0.007 | KL tr/val=0.0199/0.0182 | gap(|KL-C|) tr/val=0.0124/0.0107 | zloss tr/val=0.2667/0.2770 | rec tr/val=0.9994/0.9997 | beta=0.5916, gamma=2.5000
# [Save] Best model updated at epoch 29: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 30/100 | Train 0.9384 | Val 0.9701 | Val(ELBO) 1.8096
#   C=0.008 | KL tr/val=0.0197/0.0178 | gap(|KL-C|) tr/val=0.0119/0.0101 | zloss tr/val=0.2642/0.2755 | rec tr/val=0.9996/0.9997 | beta=0.6120, gamma=2.5000
#   [Eval@E30] MAE=0.6045, R^2=0.3592
#   [Eval@E30] yhat mean/std = -0.0030/0.5864
# [Save] Best model updated at epoch 30: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 31/100 | Train 0.9301 | Val 0.9602 | Val(ELBO) 1.7990
#   C=0.008 | KL tr/val=0.0189/0.0161 | gap(|KL-C|) tr/val=0.0109/0.0081 | zloss tr/val=0.2613/0.2721 | rec tr/val=0.9995/0.9997 | beta=0.6324, gamma=2.5000
# [Save] Best model updated at epoch 31: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 32/100 | Train 0.9252 | Val 0.9560 | Val(ELBO) 1.7949
#   C=0.008 | KL tr/val=0.0182/0.0187 | gap(|KL-C|) tr/val=0.0099/0.0104 | zloss tr/val=0.2597/0.2700 | rec tr/val=0.9996/0.9997 | beta=0.6528, gamma=2.5000
# [Save] Best model updated at epoch 32: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 33/100 | Train 0.9202 | Val 0.9567 | Val(ELBO) 1.7955
#   C=0.009 | KL tr/val=0.0182/0.0141 | gap(|KL-C|) tr/val=0.0096/0.0055 | zloss tr/val=0.2578/0.2711 | rec tr/val=0.9996/0.9997 | beta=0.6732, gamma=2.5000
# Epoch 34/100 | Train 0.9200 | Val 0.9422 | Val(ELBO) 1.7807
#   C=0.009 | KL tr/val=0.0180/0.0155 | gap(|KL-C|) tr/val=0.0092/0.0067 | zloss tr/val=0.2577/0.2656 | rec tr/val=0.9996/0.9997 | beta=0.6936, gamma=2.5000
# [Save] Best model updated at epoch 34: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 35/100 | Train 0.9116 | Val 0.9463 | Val(ELBO) 1.7857
#   C=0.009 | KL tr/val=0.0184/0.0150 | gap(|KL-C|) tr/val=0.0092/0.0059 | zloss tr/val=0.2546/0.2674 | rec tr/val=0.9995/0.9997 | beta=0.7140, gamma=2.5000
# Epoch 36/100 | Train 0.9124 | Val 0.9500 | Val(ELBO) 1.7888
#   C=0.009 | KL tr/val=0.0174/0.0140 | gap(|KL-C|) tr/val=0.0080/0.0046 | zloss tr/val=0.2550/0.2686 | rec tr/val=0.9997/0.9997 | beta=0.7344, gamma=2.5000
# Epoch 37/100 | Train 0.9024 | Val 0.9337 | Val(ELBO) 1.7731
#   C=0.010 | KL tr/val=0.0177/0.0148 | gap(|KL-C|) tr/val=0.0080/0.0052 | zloss tr/val=0.2514/0.2628 | rec tr/val=0.9995/0.9997 | beta=0.7548, gamma=2.5000
# [Save] Best model updated at epoch 37: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 38/100 | Train 0.8895 | Val 0.9263 | Val(ELBO) 1.7660
#   C=0.010 | KL tr/val=0.0165/0.0146 | gap(|KL-C|) tr/val=0.0066/0.0047 | zloss tr/val=0.2471/0.2603 | rec tr/val=0.9998/0.9997 | beta=0.7752, gamma=2.5000
# [Save] Best model updated at epoch 38: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 39/100 | Train 0.9101 | Val 0.9586 | Val(ELBO) 1.7983
#   C=0.010 | KL tr/val=0.0172/0.0117 | gap(|KL-C|) tr/val=0.0070/0.0016 | zloss tr/val=0.2539/0.2721 | rec tr/val=0.9999/0.9997 | beta=0.7956, gamma=2.5000
# Epoch 40/100 | Train 0.8993 | Val 0.9283 | Val(ELBO) 1.7672
#   C=0.010 | KL tr/val=0.0164/0.0144 | gap(|KL-C|) tr/val=0.0059/0.0039 | zloss tr/val=0.2503/0.2606 | rec tr/val=0.9997/0.9997 | beta=0.8160, gamma=2.5000
#   [Eval@E40] MAE=0.5846, R^2=0.3968
#   [Eval@E40] yhat mean/std = 0.0028/0.6143
# Epoch 41/100 | Train 0.8831 | Val 0.9215 | Val(ELBO) 1.7606
#   C=0.011 | KL tr/val=0.0162/0.0138 | gap(|KL-C|) tr/val=0.0055/0.0031 | zloss tr/val=0.2447/0.2584 | rec tr/val=0.9994/0.9997 | beta=0.8364, gamma=2.5000
# [Save] Best model updated at epoch 41: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 42/100 | Train 0.8699 | Val 0.9163 | Val(ELBO) 1.7554
#   C=0.011 | KL tr/val=0.0158/0.0144 | gap(|KL-C|) tr/val=0.0048/0.0034 | zloss tr/val=0.2401/0.2563 | rec tr/val=0.9994/0.9997 | beta=0.8568, gamma=2.5000
# [Save] Best model updated at epoch 42: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 43/100 | Train 0.8734 | Val 0.9287 | Val(ELBO) 1.7676
#   C=0.011 | KL tr/val=0.0156/0.0112 | gap(|KL-C|) tr/val=0.0043/0.0001 | zloss tr/val=0.2413/0.2614 | rec tr/val=0.9998/0.9997 | beta=0.8772, gamma=2.5000
# Epoch 44/100 | Train 0.8693 | Val 0.9118 | Val(ELBO) 1.7508
#   C=0.012 | KL tr/val=0.0153/0.0136 | gap(|KL-C|) tr/val=0.0038/0.0021 | zloss tr/val=0.2398/0.2548 | rec tr/val=0.9997/0.9997 | beta=0.8976, gamma=2.5000
# [Save] Best model updated at epoch 44: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 45/100 | Train 0.8605 | Val 0.9134 | Val(ELBO) 1.7520
#   C=0.012 | KL tr/val=0.0162/0.0116 | gap(|KL-C|) tr/val=0.0044/0.0002 | zloss tr/val=0.2365/0.2557 | rec tr/val=0.9995/0.9997 | beta=0.9180, gamma=2.5000
# Epoch 46/100 | Train 0.8759 | Val 0.9148 | Val(ELBO) 1.7538
#   C=0.012 | KL tr/val=0.0148/0.0141 | gap(|KL-C|) tr/val=0.0028/0.0020 | zloss tr/val=0.2421/0.2555 | rec tr/val=0.9995/0.9997 | beta=0.9384, gamma=2.5000
# Epoch 47/100 | Train 0.8559 | Val 0.9115 | Val(ELBO) 1.7506
#   C=0.012 | KL tr/val=0.0154/0.0114 | gap(|KL-C|) tr/val=0.0031/0.0009 | zloss tr/val=0.2349/0.2552 | rec tr/val=0.9995/0.9997 | beta=0.9588, gamma=2.5000
# [Save] Best model updated at epoch 47: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 48/100 | Train 0.8520 | Val 0.9145 | Val(ELBO) 1.7543
#   C=0.013 | KL tr/val=0.0145/0.0118 | gap(|KL-C|) tr/val=0.0020/0.0008 | zloss tr/val=0.2337/0.2562 | rec tr/val=0.9997/0.9997 | beta=0.9792, gamma=2.5000
# Epoch 49/100 | Train 0.8533 | Val 0.9115 | Val(ELBO) 1.7502
#   C=0.013 | KL tr/val=0.0153/0.0126 | gap(|KL-C|) tr/val=0.0026/0.0003 | zloss tr/val=0.2338/0.2544 | rec tr/val=0.9997/0.9997 | beta=0.9996, gamma=2.5000
# [Save] Best model updated at epoch 49: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 50/100 | Train 0.8508 | Val 0.9061 | Val(ELBO) 1.7451
#   C=0.013 | KL tr/val=0.0142/0.0113 | gap(|KL-C|) tr/val=0.0014/0.0019 | zloss tr/val=0.2332/0.2531 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
#   [Eval@E50] MAE=0.5727, R^2=0.4132
#   [Eval@E50] yhat mean/std = 0.0772/0.6265
# [Save] Best model updated at epoch 50: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 51/100 | Train 0.8395 | Val 0.9022 | Val(ELBO) 1.7414
#   C=0.013 | KL tr/val=0.0142/0.0121 | gap(|KL-C|) tr/val=0.0009/0.0013 | zloss tr/val=0.2294/0.2515 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 51: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 52/100 | Train 0.8354 | Val 0.9044 | Val(ELBO) 1.7437
#   C=0.014 | KL tr/val=0.0145/0.0119 | gap(|KL-C|) tr/val=0.0009/0.0018 | zloss tr/val=0.2278/0.2524 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 53/100 | Train 0.8369 | Val 0.8999 | Val(ELBO) 1.7392
#   C=0.014 | KL tr/val=0.0148/0.0111 | gap(|KL-C|) tr/val=0.0014/0.0028 | zloss tr/val=0.2282/0.2511 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 53: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 54/100 | Train 0.8320 | Val 0.9015 | Val(ELBO) 1.7404
#   C=0.014 | KL tr/val=0.0149/0.0109 | gap(|KL-C|) tr/val=0.0011/0.0033 | zloss tr/val=0.2265/0.2516 | rec tr/val=0.9999/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 55/100 | Train 0.8331 | Val 0.9047 | Val(ELBO) 1.7430
#   C=0.014 | KL tr/val=0.0136/0.0122 | gap(|KL-C|) tr/val=0.0020/0.0022 | zloss tr/val=0.2273/0.2520 | rec tr/val=0.9998/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 56/100 | Train 0.8263 | Val 0.9009 | Val(ELBO) 1.7387
#   C=0.015 | KL tr/val=0.0133/0.0122 | gap(|KL-C|) tr/val=0.0023/0.0025 | zloss tr/val=0.2251/0.2505 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 57/100 | Train 0.8376 | Val 0.9062 | Val(ELBO) 1.7454
#   C=0.015 | KL tr/val=0.0150/0.0124 | gap(|KL-C|) tr/val=0.0019/0.0026 | zloss tr/val=0.2284/0.2528 | rec tr/val=0.9997/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 58/100 | Train 0.8217 | Val 0.8984 | Val(ELBO) 1.7367
#   C=0.015 | KL tr/val=0.0138/0.0114 | gap(|KL-C|) tr/val=0.0022/0.0038 | zloss tr/val=0.2233/0.2501 | rec tr/val=0.9997/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 58: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 59/100 | Train 0.8166 | Val 0.8898 | Val(ELBO) 1.7282
#   C=0.016 | KL tr/val=0.0140/0.0105 | gap(|KL-C|) tr/val=0.0022/0.0051 | zloss tr/val=0.2215/0.2475 | rec tr/val=0.9999/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 59: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 60/100 | Train 0.8057 | Val 0.8859 | Val(ELBO) 1.7241
#   C=0.016 | KL tr/val=0.0128/0.0103 | gap(|KL-C|) tr/val=0.0031/0.0055 | zloss tr/val=0.2182/0.2462 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
#   [Eval@E60] MAE=0.5646, R^2=0.4345
#   [Eval@E60] yhat mean/std = 0.0013/0.6558
# [Save] Best model updated at epoch 60: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 61/100 | Train 0.8134 | Val 0.8964 | Val(ELBO) 1.7349
#   C=0.016 | KL tr/val=0.0132/0.0108 | gap(|KL-C|) tr/val=0.0029/0.0053 | zloss tr/val=0.2207/0.2497 | rec tr/val=0.9994/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 62/100 | Train 0.8085 | Val 0.8879 | Val(ELBO) 1.7267
#   C=0.016 | KL tr/val=0.0135/0.0106 | gap(|KL-C|) tr/val=0.0031/0.0057 | zloss tr/val=0.2189/0.2470 | rec tr/val=0.9997/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 63/100 | Train 0.7952 | Val 0.8820 | Val(ELBO) 1.7208
#   C=0.017 | KL tr/val=0.0134/0.0109 | gap(|KL-C|) tr/val=0.0032/0.0058 | zloss tr/val=0.2143/0.2448 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 63: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 64/100 | Train 0.8119 | Val 0.8808 | Val(ELBO) 1.7200
#   C=0.017 | KL tr/val=0.0138/0.0104 | gap(|KL-C|) tr/val=0.0034/0.0064 | zloss tr/val=0.2200/0.2447 | rec tr/val=0.9994/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 64: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 65/100 | Train 0.7945 | Val 0.8800 | Val(ELBO) 1.7186
#   C=0.017 | KL tr/val=0.0132/0.0106 | gap(|KL-C|) tr/val=0.0040/0.0066 | zloss tr/val=0.2142/0.2442 | rec tr/val=0.9994/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 65: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 66/100 | Train 0.7854 | Val 0.8795 | Val(ELBO) 1.7176
#   C=0.017 | KL tr/val=0.0128/0.0103 | gap(|KL-C|) tr/val=0.0047/0.0071 | zloss tr/val=0.2111/0.2439 | rec tr/val=0.9998/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 66: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 67/100 | Train 0.7858 | Val 0.8745 | Val(ELBO) 1.7134
#   C=0.018 | KL tr/val=0.0140/0.0106 | gap(|KL-C|) tr/val=0.0037/0.0071 | zloss tr/val=0.2109/0.2424 | rec tr/val=0.9997/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 67: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 68/100 | Train 0.7831 | Val 0.8817 | Val(ELBO) 1.7202
#   C=0.018 | KL tr/val=0.0150/0.0105 | gap(|KL-C|) tr/val=0.0029/0.0075 | zloss tr/val=0.2096/0.2448 | rec tr/val=0.9998/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 69/100 | Train 0.7889 | Val 0.8915 | Val(ELBO) 1.7288
#   C=0.018 | KL tr/val=0.0151/0.0105 | gap(|KL-C|) tr/val=0.0035/0.0077 | zloss tr/val=0.2116/0.2477 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 70/100 | Train 0.7839 | Val 0.8817 | Val(ELBO) 1.7193
#   C=0.018 | KL tr/val=0.0166/0.0101 | gap(|KL-C|) tr/val=0.0023/0.0084 | zloss tr/val=0.2093/0.2446 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
#   [Eval@E70] MAE=0.5604, R^2=0.4346
#   [Eval@E70] yhat mean/std = 0.0962/0.6762
# Epoch 71/100 | Train 0.7804 | Val 0.8770 | Val(ELBO) 1.7151
#   C=0.019 | KL tr/val=0.0130/0.0102 | gap(|KL-C|) tr/val=0.0057/0.0086 | zloss tr/val=0.2093/0.2431 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 72/100 | Train 0.7759 | Val 0.8765 | Val(ELBO) 1.7149
#   C=0.019 | KL tr/val=0.0137/0.0104 | gap(|KL-C|) tr/val=0.0053/0.0087 | zloss tr/val=0.2076/0.2430 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 73/100 | Train 0.7877 | Val 0.8839 | Val(ELBO) 1.7221
#   C=0.019 | KL tr/val=0.0141/0.0101 | gap(|KL-C|) tr/val=0.0052/0.0092 | zloss tr/val=0.2115/0.2456 | rec tr/val=0.9993/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 74/100 | Train 0.7713 | Val 0.8749 | Val(ELBO) 1.7134
#   C=0.020 | KL tr/val=0.0121/0.0099 | gap(|KL-C|) tr/val=0.0075/0.0096 | zloss tr/val=0.2065/0.2426 | rec tr/val=0.9994/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 75/100 | Train 0.7686 | Val 0.8739 | Val(ELBO) 1.7120
#   C=0.020 | KL tr/val=0.0150/0.0109 | gap(|KL-C|) tr/val=0.0052/0.0090 | zloss tr/val=0.2046/0.2418 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 75: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 76/100 | Train 0.7691 | Val 0.8769 | Val(ELBO) 1.7145
#   C=0.020 | KL tr/val=0.0138/0.0100 | gap(|KL-C|) tr/val=0.0067/0.0101 | zloss tr/val=0.2052/0.2430 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 77/100 | Train 0.7628 | Val 0.8723 | Val(ELBO) 1.7108
#   C=0.020 | KL tr/val=0.0130/0.0104 | gap(|KL-C|) tr/val=0.0074/0.0099 | zloss tr/val=0.2033/0.2415 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 77: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 78/100 | Train 0.7596 | Val 0.8717 | Val(ELBO) 1.7093
#   C=0.021 | KL tr/val=0.0145/0.0093 | gap(|KL-C|) tr/val=0.0061/0.0113 | zloss tr/val=0.2016/0.2414 | rec tr/val=0.9997/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 78: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 79/100 | Train 0.7609 | Val 0.8665 | Val(ELBO) 1.7045
#   C=0.021 | KL tr/val=0.0137/0.0097 | gap(|KL-C|) tr/val=0.0073/0.0112 | zloss tr/val=0.2024/0.2396 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 79: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 80/100 | Train 0.7597 | Val 0.8683 | Val(ELBO) 1.7061
#   C=0.021 | KL tr/val=0.0148/0.0100 | gap(|KL-C|) tr/val=0.0063/0.0111 | zloss tr/val=0.2016/0.2401 | rec tr/val=0.9994/0.9997 | beta=1.0200, gamma=2.5000
#   [Eval@E80] MAE=0.5554, R^2=0.4496
#   [Eval@E80] yhat mean/std = 0.0159/0.7085
# Epoch 81/100 | Train 0.7538 | Val 0.8712 | Val(ELBO) 1.7088
#   C=0.021 | KL tr/val=0.0134/0.0097 | gap(|KL-C|) tr/val=0.0080/0.0117 | zloss tr/val=0.2000/0.2411 | rec tr/val=0.9997/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 82/100 | Train 0.7577 | Val 0.8699 | Val(ELBO) 1.7069
#   C=0.022 | KL tr/val=0.0150/0.0091 | gap(|KL-C|) tr/val=0.0067/0.0126 | zloss tr/val=0.2008/0.2407 | rec tr/val=0.9997/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 83/100 | Train 0.7469 | Val 0.8810 | Val(ELBO) 1.7181
#   C=0.022 | KL tr/val=0.0127/0.0097 | gap(|KL-C|) tr/val=0.0093/0.0122 | zloss tr/val=0.1979/0.2443 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 84/100 | Train 0.7458 | Val 0.8667 | Val(ELBO) 1.7047
#   C=0.022 | KL tr/val=0.0107/0.0091 | gap(|KL-C|) tr/val=0.0116/0.0132 | zloss tr/val=0.1981/0.2399 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 85/100 | Train 0.7455 | Val 0.8634 | Val(ELBO) 1.7014
#   C=0.022 | KL tr/val=0.0135/0.0094 | gap(|KL-C|) tr/val=0.0090/0.0131 | zloss tr/val=0.1971/0.2387 | rec tr/val=0.9997/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 85: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 86/100 | Train 0.7579 | Val 0.8723 | Val(ELBO) 1.7105
#   C=0.023 | KL tr/val=0.0151/0.0088 | gap(|KL-C|) tr/val=0.0077/0.0140 | zloss tr/val=0.2008/0.2420 | rec tr/val=0.9999/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 87/100 | Train 0.7522 | Val 0.8610 | Val(ELBO) 1.6988
#   C=0.023 | KL tr/val=0.0114/0.0098 | gap(|KL-C|) tr/val=0.0116/0.0132 | zloss tr/val=0.2001/0.2376 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 87: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 88/100 | Train 0.7388 | Val 0.8732 | Val(ELBO) 1.7105
#   C=0.023 | KL tr/val=0.0130/0.0101 | gap(|KL-C|) tr/val=0.0103/0.0133 | zloss tr/val=0.1949/0.2416 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 89/100 | Train 0.7395 | Val 0.8681 | Val(ELBO) 1.7065
#   C=0.024 | KL tr/val=0.0137/0.0097 | gap(|KL-C|) tr/val=0.0099/0.0139 | zloss tr/val=0.1949/0.2403 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 90/100 | Train 0.7385 | Val 0.8625 | Val(ELBO) 1.7003
#   C=0.024 | KL tr/val=0.0149/0.0094 | gap(|KL-C|) tr/val=0.0090/0.0144 | zloss tr/val=0.1942/0.2383 | rec tr/val=0.9998/0.9997 | beta=1.0200, gamma=2.5000
#   [Eval@E90] MAE=0.5531, R^2=0.4553
#   [Eval@E90] yhat mean/std = -0.0277/0.7065
# Epoch 91/100 | Train 0.7300 | Val 0.8594 | Val(ELBO) 1.6971
#   C=0.024 | KL tr/val=0.0144/0.0094 | gap(|KL-C|) tr/val=0.0097/0.0148 | zloss tr/val=0.1914/0.2372 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# [Save] Best model updated at epoch 91: models/gdsc/gdsc_best_Huber_latest.pt
# Epoch 92/100 | Train 0.7327 | Val 0.8703 | Val(ELBO) 1.7085
#   C=0.024 | KL tr/val=0.0131/0.0092 | gap(|KL-C|) tr/val=0.0112/0.0152 | zloss tr/val=0.1927/0.2412 | rec tr/val=0.9999/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 93/100 | Train 0.7361 | Val 0.8659 | Val(ELBO) 1.7034
#   C=0.025 | KL tr/val=0.0137/0.0092 | gap(|KL-C|) tr/val=0.0109/0.0154 | zloss tr/val=0.1937/0.2394 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 94/100 | Train 0.7292 | Val 0.8634 | Val(ELBO) 1.7005
#   C=0.025 | KL tr/val=0.0137/0.0097 | gap(|KL-C|) tr/val=0.0112/0.0152 | zloss tr/val=0.1914/0.2382 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 95/100 | Train 0.7215 | Val 0.8712 | Val(ELBO) 1.7096
#   C=0.025 | KL tr/val=0.0115/0.0093 | gap(|KL-C|) tr/val=0.0137/0.0159 | zloss tr/val=0.1894/0.2415 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 96/100 | Train 0.7225 | Val 0.8605 | Val(ELBO) 1.6988
#   C=0.025 | KL tr/val=0.0119/0.0096 | gap(|KL-C|) tr/val=0.0136/0.0158 | zloss tr/val=0.1897/0.2377 | rec tr/val=0.9994/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 97/100 | Train 0.7262 | Val 0.8706 | Val(ELBO) 1.7091
#   C=0.026 | KL tr/val=0.0139/0.0085 | gap(|KL-C|) tr/val=0.0118/0.0173 | zloss tr/val=0.1902/0.2416 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 98/100 | Train 0.7189 | Val 0.8712 | Val(ELBO) 1.7089
#   C=0.026 | KL tr/val=0.0105/0.0091 | gap(|KL-C|) tr/val=0.0155/0.0169 | zloss tr/val=0.1889/0.2413 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 99/100 | Train 0.7193 | Val 0.8639 | Val(ELBO) 1.7014
#   C=0.026 | KL tr/val=0.0111/0.0087 | gap(|KL-C|) tr/val=0.0152/0.0176 | zloss tr/val=0.1888/0.2389 | rec tr/val=0.9995/0.9997 | beta=1.0200, gamma=2.5000
# Epoch 100/100 | Train 0.7255 | Val 0.8658 | Val(ELBO) 1.7026
#   C=0.027 | KL tr/val=0.0099/0.0092 | gap(|KL-C|) tr/val=0.0166/0.0173 | zloss tr/val=0.1913/0.2391 | rec tr/val=0.9996/0.9997 | beta=1.0200, gamma=2.5000
#   [Eval@E100] MAE=0.5536, R^2=0.4512
#   [Eval@E100] yhat mean/std = 0.0544/0.7041

# %%
plot_all_curves(
    train_hist,
    val_hist,
    elbo_val_hist,
    train_rec_hist,
    val_rec_hist,
    train_kl_hist,
    val_kl_hist,
    train_z_hist,
    val_z_hist,
    C_values,
    train_capgap_hist,
    val_capgap_hist,
)

# %%
state = torch.load(best_path, map_location=device)
model.load_state_dict(state)
model.eval()  # 評価モード

eval_dl = torch.utils.data.DataLoader(
    val_ds,  # 元の val_ds でOK
    batch_size=8192,  # 好きなサイズ
    shuffle=False,
    num_workers=0,  # ★シングルプロセス
    pin_memory=False,  # ★不要
    persistent_workers=False,  # ★絶対 False
    drop_last=False,
)

ys, yhats = [], []
with torch.inference_mode():
    for xg, xd, y in eval_dl:
        xg, xd = xg.to(device), xd.to(device)
        _, _, _, yhat = model(xg, xd)
        ys.append(y.cpu().numpy())
        yhats.append(yhat.cpu().numpy())
ys = np.concatenate(ys)
yhats = np.concatenate(yhats)
mae = mean_absolute_error(ys, yhats)
r2 = r2_score(ys, yhats)

plt.figure()
plt.scatter(ys, yhats, s=8, alpha=0.4)
lims = [min(ys.min(), yhats.min()), max(ys.max(), yhats.max())]
plt.plot(lims, lims)
plt.xlabel("True y")
plt.ylabel("Predicted ŷ")
plt.title(f"Parity Plot (Val)  MAE={mae:.3f}, R²={r2:.3f}")
plt.tight_layout()
plt.show()

# %% [markdown]
# # How to eval from loading the model

# %%
# # 1. Build the model and load the trained weights
# model = GeneDrugVAE(gene_dim, drug_dim=768, proj_dim=256, hidden=512, latent=128).to(device)
# model.load_state_dict(torch.load("models/gdsc/gdsc_last.pt", map_location=device))
# model.eval()  # set to evaluation mode

# # 2. Extract latent representations (μ) for all samples
# mus = []
# with torch.no_grad():  # disable gradient computation
#     for xg, xd, _ in dl:   # ignore y (IC50), only need xg and xd
#         xg = xg.to(device, non_blocking=True)
#         xd = xd.to(device, non_blocking=True)
#         mu, lv = model.encode(xg, xd)   # encode gene + drug into latent space
#         mus.append(mu.cpu().numpy())    # collect μ on CPU

# # Concatenate all latent vectors into one array
# Z_mu = np.concatenate(mus, axis=0)
# print("Latent shape:", Z_mu.shape)

# %%
# # ---------- 1) 全サンプルの μ をバッチで抽出 ----------
# model.eval()
# mus = []
# with torch.no_grad():
#     # 推論用 DataLoader（shuffle=False）
#     infer_dl = DataLoader(ds, batch_size=8192, shuffle=False, num_workers=0)
#     for xg, xd, y in tqdm(infer_dl, desc="Encode (μ)", leave=False):
#         xg = xg.to(device, non_blocking=True)
#         xd = xd.to(device, non_blocking=True)
#         mu, logvar = model.encode(xg, xd)  # GeneDrugVAE で encode を実装している前提
#         mus.append(mu.cpu().numpy())

# Z_mu = np.concatenate(mus, axis=0)  # (N, latent)

# %%
# # 可視化用メタ：薬ラベル & Z_score（元の ds に対応する順序を確保）
# # cellline_small の順序が ds と一致している前提（Dataset 内でそのまま index を使っている実装ならOK）
# meta_df = cellline_small.reset_index(drop=True).copy()
# # NAME が無い場合は SMILES を代用
# drug_label = meta_df["NAME"] if "NAME" in meta_df.columns else meta_df["SMILES"]
# zscore = meta_df["Z_score"].values
# cellline = meta_df["COSMIC_ID"]

# %%
# X0 = StandardScaler(with_mean=True, with_std=True).fit_transform(Z_mu)
# X = (
#     PCA(n_components=min(100, X0.shape[1]), random_state=42)
#     .fit_transform(X0)
#     .astype("float32")
# )

# umap2d = umap.UMAP(
#     n_neighbors=40,
#     min_dist=0.05,
#     metric="cosine",
#     init="spectral",
#     densmap=True,
#     random_state=42,
#     low_memory=True,
#     verbose=True,
# ).fit_transform(X)

# %%
# plt.figure()
# sc = plt.scatter(umap2d[:, 0], umap2d[:, 1], s=6, c=zscore, alpha=0.7)
# cb = plt.colorbar(sc)
# cb.set_label("Z_score")
# plt.xlabel("UMAP 1")
# plt.ylabel("UMAP 2")
# plt.title("UMAP colored by Z_score")
# plt.tight_layout()
# plt.show()

# %%
# # 入力: umap2d (N,2), drug_label (N,), zscore (N,)
# labs = pd.Series(drug_label).astype(str).str.strip().values
# z = np.asarray(zscore, dtype=float)

# # 座標で集約（丸めて同一点判定）
# xy = np.round(umap2d, 6)
# df = pd.DataFrame({"x": xy[:, 0], "y": xy[:, 1], "drug": labs, "z": z})

# # 各座標で「z が最小の薬」を代表に採用（効きが強い薬）
# idx = df.groupby(["x", "y"])["z"].idxmin()
# rep = df.loc[idx].reset_index(drop=True)  # x,y,drug,z が 1行/座標

# # 可視化（Top-20 + Other）
# vc = rep["drug"].value_counts()
# top_k = 20
# top = list(vc.head(top_k).index)

# cmap = plt.colormaps.get_cmap("tab20")
# colors = {d: cmap(i / (top_k - 1)) for i, d in enumerate(top)}
# other_color = (0.5, 0.5, 0.5, 0.25)

# plt.figure(figsize=(9, 7))
# # Otherを下地に
# m_other = ~rep["drug"].isin(top)
# plt.scatter(
#     rep.loc[m_other, "x"],
#     rep.loc[m_other, "y"],
#     s=6,
#     alpha=0.30,
#     color=other_color,
#     rasterized=True,
#     zorder=1,
#     label="Other",
#     edgecolors="none",
# )
# # Top-20 を重ねる
# for d in top:
#     m = rep["drug"].values == d
#     if m.any():
#         plt.scatter(
#             rep.loc[m, "x"],
#             rep.loc[m, "y"],
#             s=12,
#             alpha=0.95,
#             color=colors[d],
#             label=d,
#             rasterized=True,
#             zorder=3,
#             edgecolors="none",
#         )

# plt.xlabel("UMAP 1")
# plt.ylabel("UMAP 2")
# plt.title("UMAP – winner-takes-all by drug (min Z_score)")
# plt.legend(
#     bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8, frameon=False, ncol=2
# )
# plt.tight_layout()
# plt.show()

# %%
# labs = pd.Series(drug_label).astype(str).str.strip().values
# drug = "Cisplatin"  # 例

# m = labs == drug
# plt.figure(figsize=(7, 6))
# plt.hexbin(umap2d[m, 0], umap2d[m, 1], gridsize=80, mincnt=1, norm=LogNorm())
# cb = plt.colorbar()
# cb.set_label("count (log)")
# plt.title(f"UMAP density – {drug}")
# plt.xlabel("UMAP 1")
# plt.ylabel("UMAP 2")
# plt.tight_layout()
# plt.show()
