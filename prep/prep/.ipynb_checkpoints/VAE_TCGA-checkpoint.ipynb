# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.model_selection import train_test_split

# %%
# %load_ext autoreload
# %autoreload 2
    
from vae import VAE

# %%
df = pd.read_csv('dataset/tcga/gene_exp.csv.gz', index_col=0)
df
# Out:
#       cases.submitter_id      A1BG      A1CF       A2M     A2ML1    A4GALT  \
# 0           TCGA-OR-A5LL -0.738090 -0.358869 -1.284364 -0.662174  0.071062
# 1           TCGA-OR-A5J7 -0.579840 -0.383298  0.212061 -0.623405 -0.529421
# 2           TCGA-P6-A5OG  0.501265 -0.398129  0.612546 -0.707374  0.259545
# 6           TCGA-OR-A5J8 -0.618986 -0.398129  1.094104 -0.583765  1.155040
# 7           TCGA-OR-A5JL -0.575391 -0.309080 -0.257669 -0.000349 -0.863802
# ...                  ...       ...       ...       ...       ...       ...
# 10682       TCGA-DU-8168 -0.495089 -0.310761 -0.168205  0.669120 -1.439784
# 10683       TCGA-DU-6392  1.056665 -0.384697  1.255113 -0.552191 -0.663550
# 10687       TCGA-HT-A74H  0.061909 -0.390948  0.128906  0.822252 -0.397182
# 10688       TCGA-HT-7470  0.046798 -0.391460  0.466210  0.916859 -1.036840
# 10689       TCGA-HT-7606  3.005829 -0.370522  0.461792 -0.255289 -1.475401
#
#           AADAC     AADAT     AAMDC      AARD  ...     ZNRF1     ZNRF3  \
# 0      3.991960 -1.507428  1.583543  1.452025  ... -0.035460  1.290557
# 1     -0.373525 -0.889171  4.461759 -0.721811  ... -0.683419 -0.812265
# 2     -0.645832  0.036936  0.411848 -0.234270  ...  0.116915 -1.172862
# 6     -0.674528  0.556962  0.336370 -0.568159  ...  0.230676 -0.589812
# 7     -0.056424 -0.560281  0.497837 -0.535786  ... -1.027670  0.259927
# ...         ...       ...       ...       ...  ...       ...       ...
# 10682 -0.648848  2.125469  0.043546 -0.577613  ...  0.858557  0.673450
# 10683 -0.674528  1.718347 -1.407837  0.141752  ...  1.190066  0.320155
# 10687 -0.647815  0.600416 -0.256046 -0.570193  ... -1.134421 -0.352989
# 10688 -0.674528  1.064147 -0.368759 -0.178688  ...  0.047559  1.022071
# 10689 -0.674528  2.223479  0.779309 -0.689560  ...  1.270932  1.043936
#
#             ZP3   ZSCAN16   ZSCAN18   ZSCAN31    ZSWIM5    ZSWIM6     ZWINT  \
# 0     -0.139355 -0.702613 -0.926826  0.604660  2.004359 -0.153295 -2.592233
# 1      0.572096 -1.386443 -1.057612 -0.939410  0.140051 -0.955227  1.017701
# 2      0.172996 -0.706473  0.292523 -2.336992 -1.764804  2.105065  1.142627
# 6     -1.316565 -1.685371  0.263213 -1.948471  0.314336 -0.533600  0.018025
# 7      0.202159 -1.497235 -0.230091  0.249226  1.426305 -1.209734 -0.579039
# ...         ...       ...       ...       ...       ...       ...       ...
# 10682 -2.524928  0.289409  1.074694  0.190407  0.922621  2.062846  0.496325
# 10683 -0.236838 -0.011876  1.320254 -0.745764  1.267073  0.759521  0.014602
# 10687  0.678500 -0.576134  1.564978 -0.707345  0.251465 -0.209969 -2.623774
# 10688 -0.514832 -0.708323  1.325688 -0.075622  1.067387  1.337376 -1.864503
# 10689  0.332743  1.406919  1.016909  0.485747  2.063694  1.826329  0.415908
#
#             ZYX
# 0     -2.581240
# 1     -2.477873
# 2      0.313310
# 6      1.441008
# 7     -2.153087
# ...         ...
# 10682 -0.730090
# 10683  0.815270
# 10687 -1.390789
# 10688 -1.692229
# 10689 -0.243217
#
# [4416 rows x 6255 columns]

# %%
# ---- Data Prep ----
input_data = torch.tensor(df.iloc[:, 1:].values, dtype=torch.float32)
n_samples, input_dim = input_data.shape

# train / val split
train_data, val_data = train_test_split(input_data, test_size=0.2, random_state=42)
train_loader = DataLoader(TensorDataset(train_data), batch_size=64, shuffle=True)
val_loader   = DataLoader(TensorDataset(val_data),   batch_size=64, shuffle=False)

# %%
train_data

# %%
# ---- model/optimizer ----
if torch.cuda.is_available():
    device = "cuda"
elif torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = "mps"
else:
    device = "cpu"
model = VAE(input_dim=input_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
# ---- log containers ----
history = {
    "train_loss": [], "val_loss": [],
    "train_recon": [], "val_recon": [],
    "train_kld": [], "val_kld": []
}

num_epochs = 300
C_max = 10.0
T = 200

for epoch in range(num_epochs):
    beta = min(1.0, epoch/50)
    C    = min(C_max, C_max * epoch / T)   # <- use C_max consistently
    margin = 2.0                          

    # ===== Train =====
    model.train()
    train_loss = train_recon = train_kld = 0.0   # ← エポック毎に初期化
    for (x,) in train_loader:
        x = x.to(device)
        x, xrec, mu, logvar = model(x)
        loss_dict = model.loss_function(x, xrec, mu, logvar, beta=beta, capacity=C, margin=margin)
        loss = loss_dict["loss"]

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        bsz = x.size(0)
        train_loss  += loss.item() * bsz
        train_recon += loss_dict["recons_loss"].item() * bsz
        train_kld   += loss_dict["KLD"].item() * bsz

    n_train = len(train_loader.dataset)
    train_loss  /= n_train
    train_recon /= n_train
    train_kld   /= n_train

    # ===== Validation =====
    model.eval()
    val_loss = val_recon = val_kld = 0.0
    with torch.no_grad():
        for (x,) in val_loader:
            x = x.to(device)
            x, xrec, mu, logvar = model(x)
            # pass margin here too
            loss_dict = model.loss_function(x, xrec, mu, logvar,
                                            beta=beta, capacity=C, margin=margin)
            loss = loss_dict["loss"]

            bsz = x.size(0)
            val_loss  += loss.item() * bsz
            val_recon += loss_dict["recons_loss"].item() * bsz
            val_kld   += loss_dict["KLD"].item() * bsz

    n_val = len(val_loader.dataset)
    val_loss  /= n_val
    val_recon /= n_val
    val_kld   /= n_val

    # ---- save to history ----
    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_recon"].append(train_recon)
    history["val_recon"].append(val_recon)
    history["train_kld"].append(train_kld)
    history["val_kld"].append(val_kld)

    if epoch % 10 == 0:
        print(
            f"Epoch {epoch:3d} | "
            f"Train L:{train_loss:.4f} (Rec:{train_recon:.4f}, KL:{train_kld:.4f}) | "
            f"Val L:{val_loss:.4f} (Rec:{val_recon:.4f}, KL:{val_kld:.4f}) "
            f"| beta={beta:.2f} C={C:.2f}"
        )
# Out:
# Epoch   0 | Train L:0.9741 (Rec:0.9741, KL:188.6657) | Val L:0.8381 (Rec:0.8381, KL:703.3986) | beta=0.00 C=0.00
# Epoch  10 | Train L:0.8410 (Rec:0.8318, KL:1.9711) | Val L:0.8182 (Rec:0.8182, KL:1.8046) | beta=0.20 C=0.50
# Epoch  20 | Train L:0.8286 (Rec:0.8205, KL:2.1694) | Val L:0.8370 (Rec:0.8370, KL:1.3545) | beta=0.40 C=1.00
# Epoch  30 | Train L:0.8015 (Rec:0.7961, KL:2.6145) | Val L:0.7641 (Rec:0.7641, KL:2.9114) | beta=0.60 C=1.50
# Epoch  40 | Train L:0.8242 (Rec:0.8090, KL:2.4360) | Val L:0.7728 (Rec:0.7728, KL:2.3996) | beta=0.80 C=2.00
# Epoch  50 | Train L:0.8113 (Rec:0.8003, KL:2.7714) | Val L:0.7564 (Rec:0.7564, KL:3.4834) | beta=1.00 C=2.50
# Epoch  60 | Train L:0.7989 (Rec:0.7946, KL:2.4061) | Val L:0.7716 (Rec:0.7716, KL:2.6117) | beta=1.00 C=3.00
# Epoch  70 | Train L:0.7825 (Rec:0.7616, KL:3.5753) | Val L:0.7584 (Rec:0.7584, KL:2.5494) | beta=1.00 C=3.50
# Epoch  80 | Train L:0.7567 (Rec:0.7516, KL:3.8178) | Val L:0.7362 (Rec:0.7362, KL:3.0510) | beta=1.00 C=4.00
# Epoch  90 | Train L:0.7608 (Rec:0.7576, KL:3.9909) | Val L:0.7481 (Rec:0.7465, KL:2.8739) | beta=1.00 C=4.50
# Epoch 100 | Train L:0.7327 (Rec:0.7327, KL:4.5639) | Val L:0.6916 (Rec:0.6916, KL:4.9616) | beta=1.00 C=5.00
# Epoch 110 | Train L:0.7300 (Rec:0.7180, KL:5.0951) | Val L:0.6926 (Rec:0.6926, KL:4.9727) | beta=1.00 C=5.50
# Epoch 120 | Train L:0.7005 (Rec:0.6993, KL:5.9051) | Val L:0.8617 (Rec:0.7073, KL:3.8838) | beta=1.00 C=6.00
# Epoch 130 | Train L:0.7180 (Rec:0.7005, KL:6.4476) | Val L:0.6805 (Rec:0.6805, KL:5.2465) | beta=1.00 C=6.50
# Epoch 140 | Train L:0.6737 (Rec:0.6737, KL:6.9791) | Val L:0.6382 (Rec:0.6382, KL:7.9357) | beta=1.00 C=7.00
# Epoch 150 | Train L:0.6825 (Rec:0.6733, KL:7.1879) | Val L:0.6388 (Rec:0.6388, KL:6.2578) | beta=1.00 C=7.50
# Epoch 160 | Train L:0.6621 (Rec:0.6557, KL:7.4705) | Val L:0.6181 (Rec:0.6181, KL:7.9062) | beta=1.00 C=8.00
# Epoch 170 | Train L:0.6633 (Rec:0.6569, KL:8.0209) | Val L:0.6531 (Rec:0.6293, KL:6.7099) | beta=1.00 C=8.50
# Epoch 180 | Train L:0.6271 (Rec:0.6271, KL:8.3241) | Val L:0.5943 (Rec:0.5943, KL:8.1291) | beta=1.00 C=9.00
# Epoch 190 | Train L:0.6167 (Rec:0.6136, KL:8.8724) | Val L:0.5820 (Rec:0.5820, KL:8.4302) | beta=1.00 C=9.50
# Epoch 200 | Train L:0.6122 (Rec:0.6038, KL:9.9209) | Val L:0.5559 (Rec:0.5559, KL:9.6345) | beta=1.00 C=10.00
# Epoch 210 | Train L:0.6127 (Rec:0.5999, KL:9.7683) | Val L:0.8021 (Rec:0.5730, KL:7.8174) | beta=1.00 C=10.00
# Epoch 220 | Train L:0.5951 (Rec:0.5951, KL:9.4269) | Val L:0.5658 (Rec:0.5593, KL:8.5590) | beta=1.00 C=10.00
# Epoch 230 | Train L:0.5933 (Rec:0.5891, KL:9.9508) | Val L:0.5486 (Rec:0.5486, KL:9.5864) | beta=1.00 C=10.00
# Epoch 240 | Train L:0.6029 (Rec:0.5837, KL:10.0573) | Val L:0.5616 (Rec:0.5591, KL:8.6473) | beta=1.00 C=10.00
# Epoch 250 | Train L:0.5707 (Rec:0.5707, KL:10.1284) | Val L:0.5348 (Rec:0.5348, KL:9.3333) | beta=1.00 C=10.00
# Epoch 260 | Train L:0.5822 (Rec:0.5822, KL:9.4679) | Val L:0.5382 (Rec:0.5382, KL:8.6217) | beta=1.00 C=10.00
# Epoch 270 | Train L:0.5957 (Rec:0.5760, KL:9.4627) | Val L:0.7961 (Rec:0.5593, KL:7.8451) | beta=1.00 C=10.00
# Epoch 280 | Train L:0.5814 (Rec:0.5758, KL:9.8115) | Val L:0.5294 (Rec:0.5294, KL:9.0817) | beta=1.00 C=10.00
# Epoch 290 | Train L:0.5783 (Rec:0.5665, KL:10.1177) | Val L:0.5280 (Rec:0.5280, KL:9.1485) | beta=1.00 C=10.00

# %%
loss_keys = [
    ("train_loss", "val_loss", "VAE Total Loss", "Loss"),
    ("train_recon", "val_recon", "Reconstruction Loss (MSE)", "MSE"),
    ("train_kld", "val_kld", "KL Divergence", "KLD")
]

plt.figure(figsize=(6, 10))
for i, (train_key, val_key, title, ylabel) in enumerate(loss_keys, 1):
    plt.subplot(3, 1, i)
    plt.plot(history[train_key], label="Train")
    plt.plot(history[val_key], label="Val")
    plt.title(title)
    plt.xlabel("Epoch")
    plt.ylabel(ylabel)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
torch.save(model.state_dict(), "models/vae_tcga.pt")
